# %% [markdown]
# <a href="https://colab.research.google.com/github/rohithanandyala/rohitha-portfolio/blob/main/1_line_plot.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### Exercise 1: Line Plot Customization

# %%
import matplotlib.pyplot as plt

x = list(range(11))
y = [i**2 for i in x]

plt.plot(x, y)
plt.title("Line Plot of y = x²")
plt.xlabel("X values")
plt.ylabel("Y values (x squared)")
plt.grid(True)
plt.show()

# %%
# TASK: Create a line plot with x values ranging from 0 to 10 and y values as the square of x.
# Customize the plot by adding a title, labels for both axes, and a grid.
